# %%
from twone import RNNContainer
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.rand(1000, 3), columns=['a', 'b', 'c'])
df.head(10)
# Out:
#           a         b         c
# 0  0.601136  0.470592  0.303266
# 1  0.183717  0.067724  0.416507
# 2  0.122740  0.399694  0.351512
# 3  0.743521  0.417385  0.290364
# 4  0.768253  0.076519  0.721507
# 5  0.306141  0.965780  0.495102
# 6  0.895373  0.558301  0.589887
# 7  0.846604  0.454596  0.861629
# 8  0.323329  0.894427  0.463986
# 9  0.630586  0.117439  0.686987

# %%
feature_tags = ['a', 'b']
target_tags = ['c']

# %%
container = RNNContainer(df)

# %%
container.set_feature_tags(feature_tags)
container.set_target_tags(target_tags)

# %%
container.feature_tags
# Out:
# ['a', 'b', 'c']

# %%
container.target_tags
# Out:
# ['c_target']

# %%
container.interpolate()

# %%
container.data.tail(10)
# Out:
#             a         b         c  c_target
# 989  0.841873  0.172564  0.067726  0.020844
# 990  0.966947  0.703352  0.020844  0.949011
# 991  0.710853  0.008345  0.949011  0.523184
# 992  0.415249  0.497375  0.523184  0.051401
# 993  0.288913  0.429441  0.051401  0.232356
# 994  0.674434  0.430926  0.232356  0.876289
# 995  0.354030  0.940722  0.876289  0.328108
# 996  0.435596  0.329723  0.328108  0.291157
# 997  0.874372  0.565893  0.291157  0.671218
# 998  0.852941  0.690574  0.671218  0.211132

# %%
container._total_length
# Out:
# 1000

# %%
container.gen_batch()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-b56fcfd3fe77> in <module>()
# ----> 1 container.gen_batch()
#
# ~\twone\twone\container.py in gen_batch(self, batch, time_steps)
#     424             raise Exception('Feature tags not set, can\'t get feature data')
#     425         features = self.data[self.feature_tags]
# --> 426         # fit and transform feature data
#     427         self.fit(features)
#     428         normalized_array = self.normalize(features)
#
# D:\anaconda\lib\site-packages\numpy\core\fromnumeric.py in reshape(a, newshape, order)
#     230            [5, 6]])
#     231     """
# --> 232     return _wrapfunc(a, 'reshape', newshape, order=order)
#     233
#     234
#
# D:\anaconda\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55 def _wrapfunc(obj, method, *args, **kwds):
#      56     try:
# ---> 57         return getattr(obj, method)(*args, **kwds)
#      58
#      59     # An AttributeError occurs if the object does not have
#
# ValueError: cannot reshape array of size 2997 into shape (5,200,3)

# %%
a = True if 1 == 0
# Out:
#   File "<ipython-input-15-5ccfd825206d>", line 1
#     a = True if 1 == 0
#                       ^
# SyntaxError: invalid syntax

# %%
a is True
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d73d90dd0418> in <module>()
# ----> 1 a is True
#
# NameError: name 'a' is not defined

# %%
a = (True if 1==0)
# Out:
#   File "<ipython-input-19-d394fdd6aa03>", line 1
#     a = (True if 1==0)
#                      ^
# SyntaxError: invalid syntax

# %%
a
# Out:
# True
